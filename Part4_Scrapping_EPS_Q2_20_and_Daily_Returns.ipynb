# %% [markdown]
# <a href="https://colab.research.google.com/github/realmistic/pysteps-basic-fin-analysis/blob/master/Part4_Scrapping_EPS_Q2_20_and_Daily_Returns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **The grand idea**: check the financials reporting vs. stock performance.
#
# **Additional Links**:
# * Company guidance on earnings: https://www.investopedia.com/terms/g/guidance.asp
# * Price to earnings ratio: https://www.investopedia.com/terms/p/price-earningsratio.asp
#
# * Trading Revolut: https://www.revolut.com/legal/trading
# * (For next articles) New features Revolut: Out of Hours Orders, Limit Orders, Stop Loss Orders
#
#
# **ARTICLE OUTLINE**
#
# **Intro** The stocks ownership gives you the right to share in the profits of the company ([wiki article](https://en.wikipedia.org/wiki/Common_stock)). In an ideal world it should be highly dependant on the earnings of the company, as the price of the stock is a discounted future profits. If at some point a company earns more than previously - it might mean that the growth of a company is accelerated and the stock should be priced higher.
# That's why among other financials to follow - earnings per share (EPS) is one of the most important one. Every quarter analysts make predictions on the company profits (or losses) and then check those predictions vs. actual reported EPS.
# If the company is doing better than predicted - it should cause the stocks price increast, and vice versa.
#
# In this article we aim to test this at scale - for hundreds of stocks that reported earnings in 2020 Q2. We will check the dependency of a stock's price fluctuation vs. actual EPS, predicted EPS, and Surprise
#
# **Part 0** Describe scraping - HTTP request with Params, Chrome Dev tools - check DOM (span, table, tr, tags) and apply that with Beautiful Soup
#
# **Part 4.1** Describe 1 day financials for Facebook. Important caveat : reporting date is wrong on the website (it is 1 day earlier - for the most of large stocks)
#
# **Part 1** Pack everything in 1 function to get a weekly stats on the dates and EPS
#
# **Part 4.2** Get stock returns and volume for all found tickers in Yahoo finance -> join the datasets on a Ticker (Symbol) key.
#
# **Part 5** The distribution of returns and the visualisation
#
#
# **Conclusion** We've shown how to scrape the financial predictions from a website and how to connect them together with the stock returns. Q2'20 seems to be a very successfull quarter for the top 50 (on volume trade) stocks - most of them showing the positive surprise over the expected earnings-per-share (EPS) and high short-term returns. The result remains strong even after the corresponding S&P500 index returns are deducted (i.e. the top 50 stocks had higher positive growth than average index dynamics).
# When scaled to top-200 stocks - the result is not that simple - the average returns are smaller, and there is more variation in EPS and the returns.

# %% [markdown]
# # 0) Scrape ONE PAGE data on stocks financials (earnings-per-share) : STEP-BY-STEP

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (4.6.3)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
url = "https://finance.yahoo.com/calendar/earnings?from=2020-07-26&to=2020-08-01&day=2020-07-27"

# %%
r = requests.get(url)

# %%
r.ok
# Out:
# True

# %%
r.status_code
# Out:
# 200

# %%
r.headers
# Out:
# {'Referrer-Policy': 'no-referrer-when-downgrade', 'Strict-Transport-Security': 'max-age=15552000', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Security-Policy': 'sandbox allow-downloads allow-forms allow-modals allow-same-origin allow-scripts allow-popups allow-popups-to-escape-sandbox allow-top-navigation-by-user-activation allow-presentation;', 'Content-Type': 'text/html; charset=utf-8', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Set-Cookie': 'B=89apmd9fjcqe5&b=3&s=d3; expires=Fri, 14-Aug-2021 10:39:01 GMT; path=/; domain=.yahoo.com', 'Date': 'Fri, 14 Aug 2020 10:39:01 GMT', 'Age': '0', 'Server': 'ATS', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Expect-CT': 'max-age=31536000, report-uri="http://csp.yahoo.com/beacon/csp?src=yahoocom-expect-ct-report-only"', 'X-XSS-Protection': '1; mode=block', 'X-Content-Type-Options': 'nosniff'}

# %%
r.content
# Out:
# b'<!DOCTYPE html><html id="atomic" class="NoJs desktop" lang="en-US"><head prefix="og: http://ogp.me/ns#"><script>window.performance && window.performance.mark && window.performance.mark(\'PageStart\');</script><meta charset="utf-8"/><title>Company Earnings Calendar - Yahoo Finance</title><meta name="keywords" content="Earnings Announcements, Company Earnings, EPS Estimates, Earnings Per Share, Conference Calls, Before Market Open, After Market Close"/><meta http-equiv="x-dns-prefetch-control" content="on"/><meta property="twitter:dnt" content="on"/><meta property="fb:app_id" content="90376669494"/><meta name="theme-color" content="#400090"/><meta name="viewport" content="width=device-width, initial-scale=1"/><meta name="description" lang="en-US" content="Learn when companies announce their quarterly and annual earnings, along with the latest EPS estimates and conference call times from Yahoo Finance."/><meta name="oath:guce:consent-host" content="guce.yahoo.com"/><meta name="msvalidate.01" content="A9862C0E6E1BE95BCE0BF3D0298FD58B"/><link rel="manifest" href="/manifest.json"/><link rel="dns-prefetch" href="//l.yimg.com"/><link rel="dns-prefetch" href="//s.yimg.com"/><link rel="dns-prefetch" href="//csc.beap.bc.yahoo.com"/><link rel="dns-prefetch" href="//geo.query.yahoo.com"/><link rel="dns-prefetch" href="//y.analytics.yahoo.com"/><link rel="dns-prefetch" href="//b.scorecardresearch.com"/><link rel="dns-prefetch" href="//iquery.finance.yahoo.com"/><link rel="dns-prefetch" href="//fc.yahoo.com"/><link rel="dns-prefetch" href="//video-api.yql.yahoo.com"/><link rel="dns-prefetch" href="//yrtas.btrll.com"/><link rel="dns-prefetch" href="//shim.btrll.com"/><link rel="dns-prefetch" href="//consent.cmp.oath.com"/><link rel="dns-prefetch" href="//geo.yahoo.com"/><link rel="preconnect" href="//l.yimg.com" crossorigin="anonymous"/><link rel="preconnect" href="//s.yimg.com" crossorigin="anonymous"/><link rel="preconnect" href="//csc.beap.bc.yahoo.com"/><link rel="preconnect" href="//geo.query.yahoo.com"/><link rel="preconnect" href="//y.analytics.yahoo.com"/><link rel="preconnect" href="//b.scorecardresearch.com"/><link rel="preconnect" href="//iquery.finance.yahoo.com"/><link rel="preconnect" href="//fc.yahoo.com"/><link rel="preconnect" href="//video-api.yql.yahoo.com"/><link rel="preconnect" href="//yrtas.btrll.com"/><link rel="preconnect" href="//shim.btrll.com"/><link rel="preconnect" href="//consent.cmp.oath.com"/><link rel="preconnect" href="//geo.yahoo.com"/><link rel="preconnect" href="//ads.yahoo.com"/><link rel="preload" href="/__finStreamer-worker.js" as="worker"/><link rel="preload" href="/__rapidworker-1.2.js" as="worker"/><link rel="icon" href="https://s.yimg.com/cv/apiv2/default/icons/favicon_y19_32x32_custom.svg" sizes="any"/><link rel="alternate icon" href="https://s.yimg.com/cv/apiv2/default/fp/20180826/icons/favicon_y19_32x32.ico" type="image/x-icon"/><link rel="canonical" href="https://finance.yahoo.com/calendar/earnings/"/><meta property="twitter:site" content="@YahooFinance"/><meta property="fb:pages" content="90376669494"/><meta property="og:image" content="https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo.png"/><meta property="og:description" content="Learn when companies announce their quarterly and annual earnings, along with the latest EPS estimates and conference call times from Yahoo Finance."/><meta property="og:title" content="Company Earnings Calendar - Yahoo Finance"/><meta property="twitter:description" content="Learn when companies announce their quarterly and annual earnings, along with the latest EPS estimates and conference call times from Yahoo Finance."/><meta property="twitter:title" content="Company Earnings Calendar - Yahoo Finance"/><meta property="al:ios:app_store_id" content="328412701"/><meta property="al:ios:app_name" content="Yahoo Finance"/><meta property="al:android:url" content="intent://#Intent;scheme=yfinance;action=android.intent.action.VIEW;package=com.yahoo.mobile.cli ...

# %%
soup = BeautifulSoup(r.text)

# %%
table = soup.find_all('table')

# %%
# Just 1 table found which is good
len(table)
# Out:
# 1

# %%
# Get all column names
spans = soup.table.thead.find_all('span')

# %%
columns = []
for span in spans:
  print(span.text)
  columns.append(span.text)
# Out:
# Symbol
# Company
# Earnings Call Time
# EPS Estimate
# Reported EPS
# Surprise(%)

# %%
rows = soup.table.tbody.find_all('tr')

# %%
# 100 rows in the table
len(rows)
# Out:
# 100

# %%
# read row by row
stocks_df = pd.DataFrame(columns=columns)

for row in rows:
  elems = row.find_all('td')
  dict_to_add = {}
  for i,elem in enumerate(elems):
    dict_to_add[columns[i]] = elem.text
    # if i<=2:
    #   dict_to_add[columns[i]]=elem.text
    # else:  
    #   dict_to_add[columns[i]]= float(elem.text)
  stocks_df = stocks_df.append(dict_to_add, ignore_index=True)

# %%
stocks_df
# Out:
#     Symbol                           Company  ... Reported EPS Surprise(%)
# 0      MMM                        3M Company  ...         1.78       -1.17
# 1      ABG     Asbury Automotive Group, Inc.  ...         2.52       +1.16
# 2      ASH      Ashland Global Holdings Inc.  ...         0.84       +4.74
# 3      AFL                Aflac Incorporated  ...         1.28      +20.08
# 4      AWI  Armstrong World Industries, Inc.  ...         0.75      -18.12
# ..     ...                               ...  ...          ...         ...
# 95    COWN                        Cowen Inc.  ...         5.69      +19.51
# 96   GAINM  Gladstone Investment Corporation  ...         0.13      -28.57
# 97     FTV               Fortive Corporation  ...         0.68      +16.84
# 98  FTV-PA               Fortive Corporation  ...         0.68      +16.84
# 99    GAIN  Gladstone Investment Corporation  ...         0.13      -28.57
#
# [100 rows x 6 columns]

# %%
# 100 ROWS scraped and 6 columns. We will use all columns, but Earnings Call Time as it is not supplied in many cases
  # There are some problems in the dataset:
  #  - missing values, where EPS Estimate, Reported EPS, or Surprise are unknown
  #  - need to convert numetic values to float to work with them

stocks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Symbol              100 non-null    object
#  1   Company             100 non-null    object
#  2   Earnings Call Time  100 non-null    object
#  3   EPS Estimate        100 non-null    object
#  4   Reported EPS        100 non-null    object
#  5   Surprise(%)         100 non-null    object
# dtypes: object(6)
# memory usage: 4.8+ KB

# %% [markdown]
# # 1) Pack everything in one scrape function
# * it returns stocks_df over 1 week
# * call the function during the several weeks period

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as nm 
from datetime import datetime, timedelta, date

# %%
# Need to supply weekly stats as you see on the website
# from_dt = '2020-07-26'
# to_dt = '2020-08-01'

def get_scrapped_week(from_dt, to_dt):

  # initially look at the first 100 stocks with earnings at the first day of the week (from_dt)  
  # FULL URL with PARAMS example: url = "https://finance.yahoo.com/calendar/earnings?from=2020-07-26&to=2020-08-01&day=2020-07-27" 
  url = "https://finance.yahoo.com/calendar/earnings"
  offset = 0
  size = 100
  fst = 1

  # scrape every date in the submitted interval 
  for day_date in (datetime.strptime(from_dt, '%Y-%m-%d')  + timedelta(n) for n in range(6)):
    day_dt = datetime.strftime(day_date, '%Y-%m-%d')
    print(day_dt)

    # inner cycle for iteration with offset, if more than 100 stocks earnings happenned that date  
    while True:
      # make URL request with the params
      params = {'from': from_dt, 'to': to_dt,'day': day_dt, 'offset':offset, 'size': size} 
      r = requests.get(url, params=params) 
      soup = BeautifulSoup(r.text) 

      # scrape table column names when going first time to create a correct dataframe
      if fst == 1:
        spans = soup.table.thead.find_all('span')
        columns = []
        for span in spans:
          print(span.text)
          columns.append(span.text)
        stocks_df = pd.DataFrame(columns=columns)
        fst = 0

      # scrape body with row values
      rows = soup.table.tbody.find_all('tr') 
      for row in rows:
        elems = row.find_all('td')
        dict_to_add = {}
        dict_to_add['Date'] = day_dt
        for i,elem in enumerate(elems):
          dict_to_add[columns[i]]=elem.text
        stocks_df = stocks_df.append(dict_to_add, ignore_index=True)  
      if len(rows) != 100:
        print(len(rows)+offset)
        offset = 0
        break
      else: 
        offset = offset + 100
  
  return stocks_df

# stocks_df.to_csv('stocks.csv', index = False)

# %%
stocks_df = get_scrapped_week('2020-07-05', '2020-07-11')
# Out:
# 2020-07-05
# Symbol
# Company
# Earnings Call Time
# EPS Estimate
# Reported EPS
# Surprise(%)
# 8
# 2020-07-06
# 29
# 2020-07-07
# 26
# 2020-07-08
# 23
# 2020-07-09
# 25
# 2020-07-10
# 4

# %%
stocks_df.head()
# Out:
#   Symbol                             Company  ... Surprise(%)        Date
# 0  AIABF                AirAsia Group Berhad  ...       -2400  2020-07-05
# 1   SINO  Sino-Global Shipping America, Ltd.  ...           -  2020-07-05
# 2   AXAS       Abraxas Petroleum Corporation  ...     -471.43  2020-07-05
# 3  BSTJF           Boustead Projects Limited  ...           -  2020-07-05
# 4   CIDM                      Cinedigm Corp.  ...           -  2020-07-05
#
# [5 rows x 7 columns]

# %%
stocks_df = stocks_df.append(get_scrapped_week('2020-07-12', '2020-07-18'))
# Out:
# 2020-07-12
# Symbol
# Company
# Earnings Call Time
# EPS Estimate
# Reported EPS
# Surprise(%)
# 17
# 2020-07-13
# 40
# 2020-07-14
# 39
# 2020-07-15
# 55
# 2020-07-16
# 43
# 2020-07-17
# 2

# %%
stocks_df = stocks_df.append(get_scrapped_week('2020-07-19', '2020-07-25'))
# Out:
# 2020-07-19
# Symbol
# Company
# Earnings Call Time
# EPS Estimate
# Reported EPS
# Surprise(%)
# 46
# 2020-07-20
# 103
# 2020-07-21
# 145
# 2020-07-22
# 195
# 2020-07-23
# 62
# 2020-07-24
# 11

# %%
stocks_df = stocks_df.append(get_scrapped_week('2020-07-26', '2020-08-01'))
# Out:
# 2020-07-26
# Symbol
# Company
# Earnings Call Time
# EPS Estimate
# Reported EPS
# Surprise(%)
# 129
# 2020-07-27
# 261
# 2020-07-28
# 346
# 2020-07-29
# 437
# 2020-07-30
# 181
# 2020-07-31
# 19

# %%
stocks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2246 entries, 0 to 1372
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Symbol              2246 non-null   object
#  1   Company             2246 non-null   object
#  2   Earnings Call Time  2246 non-null   object
#  3   EPS Estimate        2246 non-null   object
#  4   Reported EPS        2246 non-null   object
#  5   Surprise(%)         2246 non-null   object
#  6   Date                2246 non-null   object
# dtypes: object(7)
# memory usage: 140.4+ KB

# %% [markdown]
# # 3) Clean up : no missing values and transform text to float

# %%
filter1 = stocks_df['Surprise(%)']!='-'
filter2 = stocks_df['EPS Estimate']!='-'
filter3 = stocks_df['Reported EPS']!='-'

stocks_df_noMissing = stocks_df[filter1 & filter2 & filter3]

# %%
# Around 20% had missing values
stocks_df_noMissing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1701 entries, 0 to 1372
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Symbol              1701 non-null   object
#  1   Company             1701 non-null   object
#  2   Earnings Call Time  1701 non-null   object
#  3   EPS Estimate        1701 non-null   object
#  4   Reported EPS        1701 non-null   object
#  5   Surprise(%)         1701 non-null   object
#  6   Date                1701 non-null   object
# dtypes: object(7)
# memory usage: 106.3+ KB

# %%
# Convert to float numeric values
stocks_df_noMissing['EPS Estimate'] = stocks_df_noMissing['EPS Estimate'].astype(float)
stocks_df_noMissing['Reported EPS'] = stocks_df_noMissing['Reported EPS'].astype(float)
stocks_df_noMissing['Surprise(%)'] = stocks_df_noMissing['Surprise(%)'].astype(float)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# stocks_df_noMissing['Date'] = pd.to_datetime(stocks_df_noMissing['Date'])

# stocks_df_noMissing['Date'] = stocks_df_noMissing['Date'].astype(date)

# %%
stocks_df_noMissing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1701 entries, 0 to 1372
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Symbol              1701 non-null   object
#  1   Company             1701 non-null   object
#  2   Earnings Call Time  1701 non-null   object
#  3   EPS Estimate        1701 non-null   float64
#  4   Reported EPS        1701 non-null   float64
#  5   Surprise(%)         1701 non-null   float64
#  6   Date                1701 non-null   object
# dtypes: float64(3), object(4)
# memory usage: 106.3+ KB

# %%
stocks_df_noMissing.set_index('Symbol')
# Out:
#                                  Company  ...        Date
# Symbol                                    ...
# AIABF               AirAsia Group Berhad  ...  2020-07-05
# AXAS       Abraxas Petroleum Corporation  ...  2020-07-05
# MARK               Remark Holdings, Inc.  ...  2020-07-05
# ASPU                   Aspen Group, Inc.  ...  2020-07-06
# AMLLF                AEON Mall Co., Ltd.  ...  2020-07-06
# ...                                  ...  ...         ...
# APLS         Apellis Pharmaceuticals Inc  ...  2020-07-31
# ORC            Orchid Island Capital Inc  ...  2020-07-31
# ULH     Universal Logistics Holdings Inc  ...  2020-07-31
# LAZ                           Lazard Ltd  ...  2020-07-31
# NEXA                   Nexa Resources SA  ...  2020-07-31
#
# [1701 rows x 6 columns]

# %%
stocks_df_noMissing[stocks_df_noMissing['Symbol']=='GOOGL']
# Out:
#     Symbol        Company  ... Surprise(%)        Date
# 752  GOOGL  Alphabet Inc.  ...       23.42  2020-07-29
#
# [1 rows x 7 columns]

# %% [markdown]
# # 4) Add stocks price for the companies

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading https://files.pythonhosted.org/packages/c2/31/8b374a12b90def92a4e27d0fc595fc43635f395984e36a075244d98bd265/yfinance-0.1.54.tar.gz
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.6/dist-packages (from yfinance) (1.0.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.6/dist-packages (from yfinance) (1.18.5)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.6/dist-packages (from yfinance) (2.23.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from yfinance) (0.0.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (2020.6.20)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>=0.24->yfinance) (1.15.0)
# Building wheels for collected packages: yfinance
#   Building wheel for yfinance (setup.py) ... done
#   Created wheel for yfinance: filename=yfinance-0.1.54-py2.py3-none-any.whl size=22409 sha256=ee4e4a26a29901c5749fbaea328a820cc979bf7639d36ecdebab2b98480c6a77
#   Stored in directory: /root/.cache/pip/wheels/f9/e3/5b/ec24dd2984b12d61e0abf26289746c2436a0e7844f26f2515c
# Successfully built yfinance
# Installing collected packages: yfinance
# Successfully installed yfinance-0.1.54

# %% [markdown]
# ## 4.1) Try one stock one date --> calc returns and volume jump

# %%
import yfinance as yf
import numpy as np
import pandas as pd
from datetime import datetime  
from datetime import timedelta

# %%
# Test dates
date = datetime.strptime('2020-08-08', '%Y-%m-%d')
print(date + timedelta(days=1))
print(date - timedelta(days=1))
# Out:
# 2020-08-09 00:00:00
# 2020-08-07 00:00:00

# %%
# IMPORTANT!!! For some reason the website has incorrect data for the day (one day earniere)
# https://abc.xyz/investor/static/pdf/2020Q2_alphabet_earnings_release.pdf?cache=a881c38
stocks_df_noMissing[stocks_df_noMissing['Symbol']=='GOOGL']
# Out:
#     Symbol        Company  ... Surprise(%)        Date
# 752  GOOGL  Alphabet Inc.  ...       23.42  2020-07-29
#
# [1 rows x 7 columns]

# %%
# https://s21.q4cdn.com/399680738/files/doc_financials/2020/q2/Q2'20-FB-Financial-Results-Press-Release.pdf
# SAME! date is wrong in the datasource
stocks_df_noMissing[stocks_df_noMissing['Symbol']=='FB']
# Out:
#      Symbol         Company  ... Surprise(%)        Date
# 1023     FB  Facebook, Inc.  ...       29.59  2020-07-29
#
# [1 rows x 7 columns]

# %%
# https://seekingalpha.com/symbol/AMZN/earnings. -- announce date one day later
stocks_df_noMissing[stocks_df_noMissing['Symbol']=='AMZN']
# Out:
#     Symbol           Company  ... Surprise(%)        Date
# 743   AMZN  Amazon.com, Inc.  ...      605.48  2020-07-29
#
# [1 rows x 7 columns]

# %%
stocks_df_noMissing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1678 entries, 0 to 1332
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Symbol              1678 non-null   object
#  1   Company             1678 non-null   object
#  2   Earnings Call Time  1678 non-null   object
#  3   EPS Estimate        1678 non-null   float64
#  4   Reported EPS        1678 non-null   float64
#  5   Surprise(%)         1678 non-null   float64
#  6   Date                1678 non-null   object
# dtypes: float64(3), object(4)
# memory usage: 104.9+ KB

# %%
row = stocks_df_noMissing[stocks_df_noMissing['Symbol']=='FB']
date = row['Date'].values[0]

# %%
print(date)
# Out:
# 2020-07-29

# %%
date = datetime.strptime(row['Date'].values[0], '%Y-%m-%d')

print(date + timedelta(days=3))
print(date - timedelta(days=1))

ticker = yf.Ticker('FB')

# https://pypi.org/project/yfinance/
hist = yf.download("FB", start= date - timedelta(days=1), end=date + timedelta(days=3))
# Out:
# 2020-08-01 00:00:00
# 2020-07-28 00:00:00
# [*********************100%***********************]  1 of 1 completed

# %%
hist
# Out:
#                   Open        High  ...   Adj Close    Volume
# Date                                ...
# 2020-07-28  234.630005  234.960007  ...  230.119995  14170100
# 2020-07-29  231.139999  233.699997  ...  233.289993  13588300
# 2020-07-30  230.220001  234.889999  ...  234.500000  20615300
# 2020-07-31  255.820007  255.850006  ...  253.669998  53030000
#
# [4 rows x 6 columns]

# %%
# 2 days returns -> should be defined only for the last observation
hist['r2'] = np.log(hist['Open'] / hist['Open'].shift(2))
hist['volume_rise'] = np.log(hist['Volume'] / hist['Volume'].shift(2))

# %%
# exp(0.10)=1.10 or 10% INCREASE, AND exp(1.36)=3.9x VOLUME RISE OF TRADE FOR FACEBOOK
hist
# Out:
#                   Open        High         Low  ...    Volume        r2  volume_rise
# Date                                            ...
# 2020-07-28  234.630005  234.960007  229.830002  ...  14170100       NaN          NaN
# 2020-07-29  231.139999  233.699997  230.309998  ...  13588300       NaN          NaN
# 2020-07-30  230.220001  234.889999  229.000000  ...  20615300 -0.018974     0.374899
# 2020-07-31  255.820007  255.850006  249.000000  ...  53030000  0.101451     1.361649
#
# [4 rows x 8 columns]

# %%
# The last value of returns (r2 = 2-days return on the next morning after the event) in the dataframe
hist.r2.values[-1]
# Out:
# 0.10145051589492579

# %%
# Volume of trade rising
hist.volume_rise.values[-1]
# Out:
# 1.361648662790037

# %% [markdown]
# ## 4.15) Get S&P 500 stats

# %%
import pandas_datareader.data as pdr
# from datetime import datetime
from datetime import date
# end = date.today()
# start = datetime(year=end.year, month=end.month-1, day=end.day) 

start = datetime(2020,7,1)
end = datetime(2020,8,10)
print(f'Period 1 year until today: {start} to {end} ')

spx_index = pdr.get_data_stooq('^SPX', start, end)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal
# Period 1 year until today: 2020-07-01 00:00:00 to 2020-08-10 00:00:00

# %%
# S&P500 index was growing almost all July 2020 --> need to adjust stock growth after the reporting date
spx_index['Open'].plot.line()

# %%
# 2 days returns daily in July-Aug 2020

spx_index['r2'] = np.log(np.divide(spx_index['Open'] , spx_index['Open'].shift(2)))
spx_index['r2'].plot.line()

# %%
spx_index.head(30)
# Out:
#                Open     High      Low    Close      Volume
# Date
# 2020-08-10  3356.04  3363.29  3335.44  3360.47  2565981272
# 2020-08-07  3340.05  3352.54  3328.72  3351.28  2279160879
# 2020-08-06  3323.17  3351.03  3318.14  3349.16  2414075395
# 2020-08-05  3317.37  3330.77  3317.37  3327.77  2452040105
# 2020-08-04  3289.92  3306.84  3286.37  3306.51  2403695283
# 2020-08-03  3288.26  3302.73  3284.53  3294.61  2379546705
# 2020-07-31  3270.45  3272.17  3220.26  3271.12  3062620493
# 2020-07-30  3231.76  3250.92  3204.13  3246.22  2436861309
# 2020-07-29  3227.22  3264.74  3227.22  3258.44  2471114054
# 2020-07-28  3234.27  3243.72  3216.17  3218.44  2244363387
# 2020-07-27  3219.84  3241.43  3214.25  3239.41  2355871031
# 2020-07-24  3218.58  3227.26  3200.05  3215.63  2460505182
# 2020-07-23  3271.64  3279.99  3222.66  3235.66  2742056465
# 2020-07-22  3254.86  3279.32  3253.10  3276.02  2418091343
# 2020-07-21  3268.52  3277.29  3247.77  3257.30  2470338671
# 2020-07-20  3224.29  3258.61  3215.16  3251.84  2171304615
# 2020-07-17  3224.21  3233.52  3205.65  3224.73  2219964739
# 2020-07-16  3208.36  3220.39  3198.59  3215.57  2214117696
# 2020-07-15  3225.98  3238.28  3200.76  3226.56  2849504498
# 2020-07-14  3141.11  3200.95  3127.66  3197.52  2638225293
# 2020-07-13  3205.08  3235.32  3149.43  3155.22  2694338924
# 2020-07-10  3152.47  3186.82  3136.22  3185.04  2408266859
# 2020-07-09  3176.17  3179.78  3115.70  3152.05  2595438819
# 2020-07-08  3153.07  3171.80  3136.53  3169.94  2397542535
# 2020-07-07  3166.44  3184.15  3142.93  3145.32  2286066876
# 2020-07-06  3155.29  3182.59  3155.29  3179.72  2384007094
# 2020-07-02  3143.64  3165.81  3124.52  3130.01  2332622404
# 2020-07-01  3105.92  3128.44  3101.17  3115.86  2709350469

# %%
# Filling an array of S&P return for corresponding stock
# Important: if there is a "gap" for that particular date -> we take the closest previous value
array_returns_snp500 = []
for index,row in stocks_df_noMissing.iterrows():  
  start_dt = datetime.strptime(row['Date'], '%Y-%m-%d') - timedelta(days = 1)
  end_dt = datetime.strptime(row['Date'], '%Y-%m-%d') + timedelta(days = 3)
  # we don't have gaps more than 4 days -> try to find the closest value of S&P500 returns in the dataframe:
  cur_dt = end_dt
  while cur_dt >= start_dt:
    rez_df = spx_index[cur_dt.strftime('%Y-%m-%d')]
    if len(rez_df)>0:
      array_returns_snp500.append(rez_df.r2.values[0])
      break
    else:
      cur_dt = cur_dt - timedelta(days = 1)

# %%
len(array_returns_snp500)
# Out:
# 1678

# %%
len(stocks_df_noMissing)
# Out:
# 1678

# %% [markdown]
# ## 4.2) Get all stocks returns and volume rise

# %%
# 2 days returns on open price after earnings vs. 2 days ago
array_tickers = []
array_returns = []
array_volume_rise = []
array_volume_usd = []
array_snp500 = []

for index,row in stocks_df_noMissing.iterrows():  
  start_dt = datetime.strptime(row['Date'], '%Y-%m-%d') - timedelta(days = 1)
  end_dt = datetime.strptime(row['Date'], '%Y-%m-%d') + timedelta(days = 3)
  hist = yf.download(row['Symbol'], start = start_dt, end = end_dt)
  # We need to have a full data : volume and price for all dates calculate the returns and volume rise
  # ALSO: if end_dt is non-trading day (Sat,Sun) --> we can't directly calc the stats of returns
  if len(hist)<4:
    continue
  hist['r2'] = np.log(np.divide(hist['Open'] , hist['Open'].shift(2)))
  hist['volume_rise'] = np.log(np.divide(hist['Volume'], hist['Volume'].shift(2)))
  hist['volume_usd'] = hist['Volume'] * hist['Open']
  print(row)
  print(index)
  # print(hist)
  print('--------------')
  array_tickers.append(row['Symbol'])
  array_returns.append(hist.r2.values[-1])
  array_volume_rise.append(hist.volume_rise.values[-1])  
  array_volume_usd.append(hist.volume_usd.values[-1])
  # We only append values S&P for the stocks that have all the data
  array_snp500.append(array_returns_snp500[index])
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - GEENQ: No data found for this date range, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Symbol                                           AEOJF
# Company               AEON Financial Service Co., Ltd.
# Earnings Call Time                   Time Not Supplied
# EPS Estimate                                     14.03
# Reported EPS                                        -5
# Surprise(%)                                    -135.67
# Date                                        2020-07-07
# Name: 37, dtype: object
# 37
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                               KGSDF
# Company               Kungsleden AB (publ)
# Earnings Call Time       Time Not Supplied
# EPS Estimate                          1.25
# Reported EPS                          1.31
# Surprise(%)                            4.8
# Date                            2020-07-07
# Name: 38, dtype: object
# 38
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                  BBBY
# Company               Bed Bath & Beyond Inc.
# Earnings Call Time         Time Not Supplied
# EPS Estimate                           -1.22
# Reported EPS                           -1.96
# Surprise(%)                           -60.39
# Date                              2020-07-07
# Name: 44, dtype: object
# 44
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                GDDFF
# Company               Goodfood Market Corp.
# Earnings Call Time        Time Not Supplied
# EPS Estimate                          -0.05
# Reported EPS                           0.05
# Surprise(%)                             200
# Date                             2020-07-07
# Name: 46, dtype: object
# 46
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                            MSM
# Company               MSC Industrial Direct Co., Inc.
# Earnings Call Time                  Time Not Supplied
# EPS Estimate                                     1.16
# Reported EPS                                      1.4
# Surprise(%)                                     20.48
# Date                                       2020-07-07
# Name: 47, dtype: object
# 47
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                      SAR
# Company               Saratoga Investment Corp.
# Earnings Call Time            Time Not Supplied
# EPS Estimate                              -1.38
# Reported EPS                              -2.02
# Surprise(%)                               -46.8
# Date                                 2020-07-07
# Name: 49, dtype: object
# 49
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                                           NTIC
# Company               Northern Technologies International Corporation
# Earnings Call Time                                  Time Not Supplied
# EPS Estimate                                                    -0.06
# Reported EPS                                                    -0.11
# Surprise(%)                                                    -83.33
# Date                                                       2020-07-07
# Name: 50, dtype: object
# 50
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                             FTGFF
# Company               Firan Technology Group Corporation
# Earnings Call Time                     Time Not Supplied
# EPS Estimate                                        0.03
# Reported EPS                                        0.08
# Surprise(%)                                       166.67
# Date                                          2020-07-07
# Name: 51, dtype: object
# 51
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                         SMPL
# Company               The Simply Good Foods Company
# Earnings Call Time                Time Not Supplied
# EPS Estimate                                   0.15
# Reported EPS                                   0.26
# Surprise(%)                                   68.83
# Date                                     2020-07-07
# Name: 53, dtype: object
# 53
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             EXFO
# Company                       EXFO Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                      -0.03
# Reported EPS                        0.1
# Surprise(%)                      433.33
# Date                         2020-07-07
# Name: 56, dtype: object
# 56
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                           DRKOF
# Company               Martello Technologies Group Inc.
# Earnings Call Time                   Time Not Supplied
# EPS Estimate                                     -0.01
# Reported EPS                                     -0.02
# Surprise(%)                                     -53.85
# Date                                        2020-07-07
# Name: 58, dtype: object
# 58
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                 KSHB
# Company               KushCo Holdings, Inc.
# Earnings Call Time        Time Not Supplied
# EPS Estimate                           -0.1
# Reported EPS                          -0.11
# Surprise(%)                          -12.24
# Date                             2020-07-07
# Name: 60, dtype: object
# 60
# --------------
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Streaming output truncated to the last 5000 lines.
# EPS Estimate                       0.05
# Reported EPS                       0.06
# Surprise(%)                          25
# Date                         2020-07-28
# Name: 633, dtype: object
# 633
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                              JMP
# Company                   JMP Group LLC
# Earnings Call Time    Time Not Supplied
# EPS Estimate                      -0.07
# Reported EPS                       0.13
# Surprise(%)                      285.71
# Date                         2020-07-28
# Name: 634, dtype: object
# 634
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                GSK
# Company               GlaxoSmithKline plc
# Earnings Call Time      Time Not Supplied
# EPS Estimate                         0.51
# Reported EPS                         0.46
# Surprise(%)                          -9.8
# Date                           2020-07-28
# Name: 635, dtype: object
# 635
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                     TROW
# Company               T. Rowe Price Group, Inc.
# Earnings Call Time            Time Not Supplied
# EPS Estimate                               2.02
# Reported EPS                               2.29
# Surprise(%)                                13.2
# Date                                 2020-07-28
# Name: 636, dtype: object
# 636
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                 PGRE
# Company               Paramount Group, Inc.
# Earnings Call Time        Time Not Supplied
# EPS Estimate                           0.01
# Reported EPS                          -0.03
# Surprise(%)                         -528.57
# Date                             2020-07-28
# Name: 638, dtype: object
# 638
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             GRMN
# Company                     Garmin Ltd.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       0.39
# Reported EPS                       0.91
# Surprise(%)                      132.14
# Date                         2020-07-28
# Name: 639, dtype: object
# 639
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                      JHG
# Company               Janus Henderson Group plc
# Earnings Call Time            Time Not Supplied
# EPS Estimate                               0.52
# Reported EPS                               0.67
# Surprise(%)                               29.84
# Date                                 2020-07-28
# Name: 640, dtype: object
# 640
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                              GLAXF
# Company               GlaxoSmithKline plc
# Earnings Call Time      Time Not Supplied
# EPS Estimate                           20
# Reported EPS                         19.2
# Surprise(%)                         -4.01
# Date                           2020-07-28
# Name: 641, dtype: object
# 641
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                 WTRE
# Company               Watford Holdings Ltd.
# Earnings Call Time        Time Not Supplied
# EPS Estimate                            6.8
# Reported EPS                           9.51
# Surprise(%)                           39.96
# Date                             2020-07-28
# Name: 642, dtype: object
# 642
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                WTREP
# Company               Watford Holdings Ltd.
# Earnings Call Time        Time Not Supplied
# EPS Estimate                            6.8
# Reported EPS                           9.51
# Surprise(%)                           39.96
# Date                             2020-07-28
# Name: 643, dtype: object
# 643
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                  KOP
# Company               Koppers Holdings Inc.
# Earnings Call Time        Time Not Supplied
# EPS Estimate                              1
# Reported EPS                           1.27
# Surprise(%)                              27
# Date                             2020-07-28
# Name: 644, dtype: object
# 644
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                               UVE
# Company               Universal Insurance Holdings, Inc.
# Earnings Call Time                     Time Not Supplied
# EPS Estimate                                         0.5
# Reported EPS                                        0.52
# Surprise(%)                                            4
# Date                                          2020-07-28
# Name: 645, dtype: object
# 645
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                NRSCF
# Company               Nomura Holdings, Inc.
# Earnings Call Time        Time Not Supplied
# EPS Estimate                           32.1
# Reported EPS                          46.77
# Surprise(%)                            45.7
# Date                             2020-07-28
# Name: 646, dtype: object
# 646
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                TDOC
# Company               Teladoc Health, Inc.
# Earnings Call Time       Time Not Supplied
# EPS Estimate                         -0.23
# Reported EPS                         -0.34
# Surprise(%)                         -44.68
# Date                            2020-07-28
# Name: 647, dtype: object
# 647
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                   INOV
# Company               Inovalon Holdings, Inc.
# Earnings Call Time          Time Not Supplied
# EPS Estimate                             0.11
# Reported EPS                             0.15
# Surprise(%)                             31.58
# Date                               2020-07-28
# Name: 649, dtype: object
# 649
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                               TROX
# Company               Tronox Holdings plc
# Earnings Call Time      Time Not Supplied
# EPS Estimate                        -0.02
# Reported EPS                         0.03
# Surprise(%)                         287.5
# Date                           2020-07-28
# Name: 650, dtype: object
# 650
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                              MHO
# Company                 M/I Homes, Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       0.89
# Reported EPS                       1.89
# Surprise(%)                      113.56
# Date                         2020-07-28
# Name: 651, dtype: object
# 651
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                                     MTSI
# Company               MACOM Technology Solutions Holdings, Inc.
# Earnings Call Time                            Time Not Supplied
# EPS Estimate                                               0.21
# Reported EPS                                               0.33
# Surprise(%)                                               55.66
# Date                                                 2020-07-28
# Name: 652, dtype: object
# 652
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                 PYPL
# Company               PayPal Holdings, Inc.
# Earnings Call Time        Time Not Supplied
# EPS Estimate                           0.88
# Reported EPS                           1.07
# Surprise(%)                           22.01
# Date                             2020-07-28
# Name: 653, dtype: object
# 653
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                 MGLN
# Company               Magellan Health, Inc.
# Earnings Call Time        Time Not Supplied
# EPS Estimate                           0.82
# Reported EPS                           0.84
# Surprise(%)                            2.07
# Date                             2020-07-28
# Name: 654, dtype: object
# 654
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             HESM
# Company               Hess Midstream LP
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       0.38
# Reported EPS                       0.29
# Surprise(%)                      -24.08
# Date                         2020-07-28
# Name: 655, dtype: object
# 655
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             HOLX
# Company                   Hologic, Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       0.39
# Reported EPS                       0.75
# Surprise(%)                       94.81
# Date                         2020-07-28
# Name: 656, dtype: object
# 656
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                            HPP
# Company               Hudson Pacific Properties, Inc.
# Earnings Call Time                  Time Not Supplied
# EPS Estimate                                     0.05
# Reported EPS                                     0.02
# Surprise(%)                                    -62.26
# Date                                       2020-07-28
# Name: 658, dtype: object
# 658
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                  TTMI
# Company               TTM Technologies, Inc.
# Earnings Call Time         Time Not Supplied
# EPS Estimate                            0.14
# Reported EPS                            0.31
# Surprise(%)                           121.43
# Date                              2020-07-28
# Name: 659, dtype: object
# 659
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                     TYL
# Company               Tyler Technologies, Inc.
# Earnings Call Time           Time Not Supplied
# EPS Estimate                               1.2
# Reported EPS                              1.38
# Surprise(%)                                 15
# Date                                2020-07-28
# Name: 660, dtype: object
# 660
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                 QCOM
# Company               QUALCOMM Incorporated
# Earnings Call Time        Time Not Supplied
# EPS Estimate                           0.71
# Reported EPS                           0.86
# Surprise(%)                           21.47
# Date                             2020-07-28
# Name: 661, dtype: object
# 661
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             SAIA
# Company                      Saia, Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                        0.9
# Reported EPS                       1.07
# Surprise(%)                       19.15
# Date                         2020-07-28
# Name: 662, dtype: object
# 662
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             TTEK
# Company                Tetra Tech, Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       0.73
# Reported EPS                       0.78
# Surprise(%)                        7.29
# Date                         2020-07-28
# Name: 663, dtype: object
# 663
# --------------
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WRI-PF: No data found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# Symbol                                          SMP
# Company               Standard Motor Products, Inc.
# Earnings Call Time                Time Not Supplied
# EPS Estimate                                    0.2
# Reported EPS                                   0.52
# Surprise(%)                                  165.31
# Date                                     2020-07-28
# Name: 665, dtype: object
# 665
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                            OII
# Company               Oceaneering International, Inc.
# Earnings Call Time                  Time Not Supplied
# EPS Estimate                                    -0.21
# Reported EPS                                    -0.14
# Surprise(%)                                     34.27
# Date                                       2020-07-28
# Name: 666, dtype: object
# 666
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                                 ILPT
# Company               Industrial Logistics Properties Trust
# Earnings Call Time                        Time Not Supplied
# EPS Estimate                                           0.25
# Reported EPS                                           0.23
# Surprise(%)                                              -8
# Date                                             2020-07-28
# Name: 667, dtype: object
# 667
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             LOGM
# Company                   LogMeIn, Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       1.23
# Reported EPS                       1.54
# Surprise(%)                        24.8
# Date                         2020-07-28
# Name: 668, dtype: object
# 668
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                       MMSI
# Company               Merit Medical Systems, Inc.
# Earnings Call Time              Time Not Supplied
# EPS Estimate                                 0.07
# Reported EPS                                 0.31
# Surprise(%)                                376.92
# Date                                   2020-07-28
# Name: 669, dtype: object
# 669
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                 MKSI
# Company               MKS Instruments, Inc.
# Earnings Call Time        Time Not Supplied
# EPS Estimate                           1.18
# Reported EPS                           1.62
# Surprise(%)                           36.94
# Date                             2020-07-28
# Name: 670, dtype: object
# 670
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             MNRO
# Company                     Monro, Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                      -0.21
# Reported EPS                       0.15
# Surprise(%)                      170.42
# Date                         2020-07-28
# Name: 671, dtype: object
# 671
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             MOBL
# Company                MobileIron, Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                      -0.03
# Reported EPS                       0.04
# Surprise(%)                         225
# Date                         2020-07-28
# Name: 672, dtype: object
# 672
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                    MSA
# Company               MSA Safety Incorporated
# Earnings Call Time          Time Not Supplied
# EPS Estimate                             0.95
# Reported EPS                             1.11
# Surprise(%)                             16.47
# Date                               2020-07-28
# Name: 673, dtype: object
# 673
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             QRVO
# Company                     Qorvo, Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       1.13
# Reported EPS                        1.5
# Surprise(%)                       32.74
# Date                         2020-07-28
# Name: 674, dtype: object
# 674
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             WING
# Company                   Wingstop Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       0.29
# Reported EPS                       0.39
# Surprise(%)                       34.48
# Date                         2020-07-28
# Name: 675, dtype: object
# 675
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                            MTHRF
# Company                        M3, Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       8.09
# Reported EPS                       9.53
# Surprise(%)                       17.76
# Date                         2020-07-28
# Name: 676, dtype: object
# 676
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                              RES
# Company                       RPC, Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                      -0.14
# Reported EPS                       -0.1
# Surprise(%)                       26.47
# Date                         2020-07-28
# Name: 677, dtype: object
# 677
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                              ROL
# Company                   Rollins, Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       0.18
# Reported EPS                       0.23
# Surprise(%)                       27.78
# Date                         2020-07-28
# Name: 678, dtype: object
# 678
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                              NOW
# Company                ServiceNow, Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       1.01
# Reported EPS                       1.23
# Surprise(%)                        21.3
# Date                         2020-07-28
# Name: 679, dtype: object
# 679
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                           OIS
# Company               Oil States International, Inc.
# Earnings Call Time                 Time Not Supplied
# EPS Estimate                                   -0.47
# Reported EPS                                   -0.33
# Surprise(%)                                    30.23
# Date                                      2020-07-28
# Name: 680, dtype: object
# 680
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                               PDM
# Company               Piedmont Office Realty Trust, Inc.
# Earnings Call Time                     Time Not Supplied
# EPS Estimate                                        0.07
# Reported EPS                                        1.57
# Surprise(%)                                      2142.86
# Date                                          2020-07-28
# Name: 681, dtype: object
# 681
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                QEP
# Company               QEP Resources, Inc.
# Earnings Call Time      Time Not Supplied
# EPS Estimate                        -0.03
# Reported EPS                        -0.06
# Surprise(%)                        -106.9
# Date                           2020-07-28
# Name: 683, dtype: object
# 683
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             EGOV
# Company                        NIC Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       0.17
# Reported EPS                        0.2
# Surprise(%)                       15.61
# Date                         2020-07-28
# Name: 684, dtype: object
# 684
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             INVA
# Company                  Innoviva, Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       0.32
# Reported EPS                       0.69
# Surprise(%)                      115.62
# Date                         2020-07-28
# Name: 685, dtype: object
# 685
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                            IRT
# Company               Independence Realty Trust, Inc.
# Earnings Call Time                  Time Not Supplied
# EPS Estimate                                     0.03
# Reported EPS                                     0.01
# Surprise(%)                                       -60
# Date                                       2020-07-28
# Name: 686, dtype: object
# 686
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                               JAKK
# Company               JAKKS Pacific, Inc.
# Earnings Call Time      Time Not Supplied
# EPS Estimate                        -4.06
# Reported EPS                        -4.38
# Surprise(%)                         -7.96
# Date                           2020-07-28
# Name: 688, dtype: object
# 688
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                     VKTX
# Company               Viking Therapeutics, Inc.
# Earnings Call Time            Time Not Supplied
# EPS Estimate                              -0.14
# Reported EPS                              -0.13
# Surprise(%)                                9.09
# Date                                 2020-07-28
# Name: 689, dtype: object
# 689
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                               JAKK
# Company               JAKKS Pacific, Inc.
# Earnings Call Time      Time Not Supplied
# EPS Estimate                        -4.06
# Reported EPS                        -4.38
# Surprise(%)                         -7.96
# Date                           2020-07-28
# Name: 691, dtype: object
# 691
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                          SITE
# Company               SiteOne Landscape Supply, Inc.
# Earnings Call Time                 Time Not Supplied
# EPS Estimate                                    1.48
# Reported EPS                                    1.89
# Surprise(%)                                    28.05
# Date                                      2020-07-28
# Name: 692, dtype: object
# 692
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                     VKTX
# Company               Viking Therapeutics, Inc.
# Earnings Call Time            Time Not Supplied
# EPS Estimate                              -0.14
# Reported EPS                              -0.13
# Surprise(%)                                9.09
# Date                                 2020-07-28
# Name: 693, dtype: object
# 693
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                 URI
# Company               United Rentals, Inc.
# Earnings Call Time       Time Not Supplied
# EPS Estimate                          1.86
# Reported EPS                          3.68
# Surprise(%)                          97.53
# Date                            2020-07-28
# Name: 694, dtype: object
# 694
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             MTOR
# Company                   Meritor, Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                      -0.51
# Reported EPS                      -0.47
# Surprise(%)                        8.56
# Date                         2020-07-28
# Name: 695, dtype: object
# 695
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             SHOP
# Company                    Shopify Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       0.01
# Reported EPS                       1.05
# Surprise(%)                     7976.92
# Date                         2020-07-28
# Name: 696, dtype: object
# 696
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                     SLAB
# Company               Silicon Laboratories Inc.
# Earnings Call Time            Time Not Supplied
# EPS Estimate                               0.57
# Reported EPS                               0.74
# Surprise(%)                               30.28
# Date                                 2020-07-28
# Name: 697, dtype: object
# 697
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                               TARO
# Company               Taro Pharmaceutical Industries Ltd.
# Earnings Call Time                      Time Not Supplied
# EPS Estimate                                         1.16
# Reported EPS                                       -11.37
# Surprise(%)                                      -1080.17
# Date                                           2020-07-28
# Name: 698, dtype: object
# 698
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                        WRI
# Company               Weingarten Realty Investors
# Earnings Call Time              Time Not Supplied
# EPS Estimate                                 0.15
# Reported EPS                                 0.09
# Surprise(%)                                -41.56
# Date                                   2020-07-28
# Name: 699, dtype: object
# 699
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                              SRI
# Company                Stoneridge, Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                      -0.66
# Reported EPS                      -0.55
# Surprise(%)                       16.29
# Date                         2020-07-28
# Name: 700, dtype: object
# 700
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                             SREV
# Company               ServiceSource International, Inc.
# Earnings Call Time                    Time Not Supplied
# EPS Estimate                                      -0.05
# Reported EPS                                      -0.01
# Surprise(%)                                          80
# Date                                         2020-07-28
# Name: 701, dtype: object
# 701
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                VICI
# Company               VICI Properties Inc.
# Earnings Call Time       Time Not Supplied
# EPS Estimate                          0.36
# Reported EPS                          0.47
# Surprise(%)                          30.56
# Date                            2020-07-28
# Name: 704, dtype: object
# 704
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                         LXRX
# Company               Lexicon Pharmaceuticals, Inc.
# Earnings Call Time                Time Not Supplied
# EPS Estimate                                  -0.61
# Reported EPS                                  -0.65
# Surprise(%)                                   -6.91
# Date                                     2020-07-28
# Name: 705, dtype: object
# 705
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                    UNLRF
# Company               PT Unilever Indonesia Tbk
# Earnings Call Time            Time Not Supplied
# EPS Estimate                              53.44
# Reported EPS                                 46
# Surprise(%)                              -13.92
# Date                                 2020-07-28
# Name: 706, dtype: object
# 706
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                 R
# Company               Ryder System, Inc.
# Earnings Call Time     Time Not Supplied
# EPS Estimate                       -1.29
# Reported EPS                       -0.95
# Surprise(%)                         26.3
# Date                          2020-07-28
# Name: 707, dtype: object
# 707
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             LFUS
# Company                Littelfuse, Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       0.37
# Reported EPS                       0.71
# Surprise(%)                       91.37
# Date                         2020-07-28
# Name: 708, dtype: object
# 708
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                 LXU
# Company               LSB Industries, Inc.
# Earnings Call Time       Time Not Supplied
# EPS Estimate                         -0.48
# Reported EPS                         -0.34
# Surprise(%)                           29.9
# Date                            2020-07-28
# Name: 709, dtype: object
# 709
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                PTLKF
# Company               PT Lippo Karawaci Tbk
# Earnings Call Time        Time Not Supplied
# EPS Estimate                             -5
# Reported EPS                         -14.92
# Surprise(%)                         -198.44
# Date                             2020-07-28
# Name: 712, dtype: object
# 712
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                               SHOO
# Company               Steven Madden, Ltd.
# Earnings Call Time      Time Not Supplied
# EPS Estimate                        -0.27
# Reported EPS                        -0.19
# Surprise(%)                         29.37
# Date                           2020-07-28
# Name: 713, dtype: object
# 713
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             RDWR
# Company                    Radware Ltd.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       0.12
# Reported EPS                       0.13
# Surprise(%)                        8.33
# Date                         2020-07-28
# Name: 715, dtype: object
# 715
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                    TSEM
# Company               Tower Semiconductor Ltd.
# Earnings Call Time           Time Not Supplied
# EPS Estimate                              0.23
# Reported EPS                              0.22
# Surprise(%)                              -5.17
# Date                                2020-07-28
# Name: 716, dtype: object
# 716
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                          NMM
# Company               Navios Maritime Partners L.P.
# Earnings Call Time                Time Not Supplied
# EPS Estimate                                  -0.46
# Reported EPS                                  -0.71
# Surprise(%)                                  -53.35
# Date                                     2020-07-28
# Name: 718, dtype: object
# 718
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             LIVN
# Company                    LivaNova PLC
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       -0.3
# Reported EPS                      -0.15
# Surprise(%)                       49.32
# Date                         2020-07-28
# Name: 720, dtype: object
# 720
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             SILC
# Company                    Silicom Ltd.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       0.26
# Reported EPS                       0.26
# Surprise(%)                        0.78
# Date                         2020-07-28
# Name: 721, dtype: object
# 721
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             MGRC
# Company                McGrath RentCorp
# Earnings Call Time    Time Not Supplied
# EPS Estimate                        0.4
# Reported EPS                       0.92
# Surprise(%)                      131.74
# Date                         2020-07-28
# Name: 722, dtype: object
# 722
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                              FTI
# Company                  TechnipFMC plc
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       0.06
# Reported EPS                       0.09
# Surprise(%)                       45.16
# Date                         2020-07-28
# Name: 725, dtype: object
# 725
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                   TSU
# Company               TIM Participações S.A.
# Earnings Call Time         Time Not Supplied
# EPS Estimate                            0.08
# Reported EPS                             0.1
# Surprise(%)                            24.39
# Date                              2020-07-28
# Name: 726, dtype: object
# 726
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                    TT
# Company               Trane Technologies plc
# Earnings Call Time         Time Not Supplied
# EPS Estimate                            0.74
# Reported EPS                            1.27
# Surprise(%)                            71.16
# Date                              2020-07-28
# Name: 727, dtype: object
# 727
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                            SAPMY
# Company                      Saipem SpA
# Earnings Call Time    Time Not Supplied
# EPS Estimate                      -0.02
# Reported EPS                      -0.12
# Surprise(%)                        -510
# Date                         2020-07-28
# Name: 729, dtype: object
# 729
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                            SNYNF
# Company                          Sanofi
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       1.25
# Reported EPS                       1.28
# Surprise(%)                        2.81
# Date                         2020-07-28
# Name: 730, dtype: object
# 730
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                              TSE
# Company                    Trinseo S.A.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                      -1.62
# Reported EPS                      -2.95
# Surprise(%)                      -81.87
# Date                         2020-07-28
# Name: 731, dtype: object
# 731
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                   SPOT
# Company               Spotify Technology S.A.
# Earnings Call Time          Time Not Supplied
# EPS Estimate                            -0.45
# Reported EPS                            -1.91
# Surprise(%)                           -322.57
# Date                               2020-07-28
# Name: 732, dtype: object
# 732
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             VALE
# Company                       Vale S.A.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       0.27
# Reported EPS                       0.23
# Surprise(%)                      -13.53
# Date                         2020-07-28
# Name: 733, dtype: object
# 733
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                              SNY
# Company                          Sanofi
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       0.65
# Reported EPS                       0.71
# Surprise(%)                        8.46
# Date                         2020-07-28
# Name: 734, dtype: object
# 734
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                     GPI
# Company               Group 1 Automotive, Inc.
# Earnings Call Time           Time Not Supplied
# EPS Estimate                              0.68
# Reported EPS                              3.77
# Surprise(%)                             456.87
# Date                                2020-07-29
# Name: 736, dtype: object
# 736
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             TWOU
# Company                        2U, Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                      -0.39
# Reported EPS                      -0.34
# Surprise(%)                       13.27
# Date                         2020-07-29
# Name: 737, dtype: object
# 737
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             EGHT
# Company                       8x8, Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                      -0.12
# Reported EPS                      -0.07
# Surprise(%)                       43.55
# Date                         2020-07-29
# Name: 738, dtype: object
# 738
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                            WKCMF
# Company                Wacker Chemie AG
# Earnings Call Time    Time Not Supplied
# EPS Estimate                      -0.49
# Reported EPS                       0.07
# Surprise(%)                      114.23
# Date                         2020-07-29
# Name: 739, dtype: object
# 739
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                        WRLD
# Company               World Acceptance Corporation
# Earnings Call Time               Time Not Supplied
# EPS Estimate                                 -0.08
# Reported EPS                                  2.24
# Surprise(%)                                2831.71
# Date                                    2020-07-29
# Name: 740, dtype: object
# 740
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                    AOS
# Company               A. O. Smith Corporation
# Earnings Call Time          Time Not Supplied
# EPS Estimate                             0.42
# Reported EPS                             0.45
# Surprise(%)                              7.14
# Date                               2020-07-29
# Name: 741, dtype: object
# 741
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                        APO-PB
# Company               Apollo Global Management, Inc.
# Earnings Call Time                 Time Not Supplied
# EPS Estimate                                    0.48
# Reported EPS                                    0.46
# Surprise(%)                                    -3.56
# Date                                      2020-07-29
# Name: 742, dtype: object
# 742
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             AMZN
# Company                Amazon.com, Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       1.46
# Reported EPS                       10.3
# Surprise(%)                      605.48
# Date                         2020-07-29
# Name: 743, dtype: object
# 743
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                                    NNA
# Company               Navios Maritime Acquisition Corporation
# Earnings Call Time                          Time Not Supplied
# EPS Estimate                                             2.24
# Reported EPS                                             2.01
# Surprise(%)                                            -10.43
# Date                                               2020-07-29
# Name: 744, dtype: object
# 744
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                         CACC
# Company               Credit Acceptance Corporation
# Earnings Call Time                Time Not Supplied
# EPS Estimate                                   4.85
# Reported EPS                                    5.4
# Surprise(%)                                   11.46
# Date                                     2020-07-29
# Name: 745, dtype: object
# 745
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                             ELAN
# Company               Elanco Animal Health Incorporated
# Earnings Call Time                    Time Not Supplied
# EPS Estimate                                       0.06
# Reported EPS                                       0.09
# Surprise(%)                                       60.71
# Date                                         2020-07-29
# Name: 746, dtype: object
# 746
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                    ARW
# ...
# Earnings Call Time      Time Not Supplied
# EPS Estimate                        -0.76
# Reported EPS                        -0.63
# Surprise(%)                         16.67
# Date                           2020-07-29
# Name: 1142, dtype: object
# 1142
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                              XYL
# Company                      Xylem Inc.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       0.39
# Reported EPS                        0.4
# Surprise(%)                        3.63
# Date                         2020-07-29
# Name: 1143, dtype: object
# 1143
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                          MGI
# Company               MoneyGram International, Inc.
# Earnings Call Time                Time Not Supplied
# EPS Estimate                                  -0.06
# Reported EPS                                   0.01
# Surprise(%)                                  115.63
# Date                                     2020-07-29
# Name: 1144, dtype: object
# 1144
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                 LTC
# Company               LTC Properties, Inc.
# Earnings Call Time       Time Not Supplied
# EPS Estimate                          0.48
# Reported EPS                          0.05
# Surprise(%)                         -89.65
# Date                            2020-07-29
# Name: 1146, dtype: object
# 1146
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                   TSUKF
# Company               Toyo Suisan Kaisha, Ltd.
# Earnings Call Time           Time Not Supplied
# EPS Estimate                             61.55
# Reported EPS                             82.26
# Surprise(%)                              33.64
# Date                                2020-07-29
# Name: 1148, dtype: object
# 1148
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                         KNSA
# Company               Kiniksa Pharmaceuticals, Ltd.
# Earnings Call Time                Time Not Supplied
# EPS Estimate                                  -0.63
# Reported EPS                                  -0.65
# Surprise(%)                                   -3.83
# Date                                     2020-07-29
# Name: 1150, dtype: object
# 1150
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                  MIXT
# Company               MiX Telematics Limited
# Earnings Call Time         Time Not Supplied
# EPS Estimate                           -0.58
# Reported EPS                            1.97
# Surprise(%)                           440.76
# Date                              2020-07-29
# Name: 1153, dtype: object
# 1153
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                              MMP
# Company               Magellan Midstream Partners, L.P.
# Earnings Call Time                    Time Not Supplied
# EPS Estimate                                       0.74
# Reported EPS                                       0.59
# Surprise(%)                                      -20.27
# Date                                         2020-07-29
# Name: 1154, dtype: object
# 1154
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                              LIN
# Company                       Linde plc
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       1.65
# Reported EPS                        1.9
# Surprise(%)                       15.22
# Date                         2020-07-29
# Name: 1155, dtype: object
# 1155
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                                     TPL
# Company               Texas Pacific Land Trust
# Earnings Call Time           Time Not Supplied
# EPS Estimate                              6.57
# Reported EPS                              3.56
# Surprise(%)                             -45.81
# Date                                2020-07-29
# Name: 1157, dtype: object
# 1157
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             MTLS
# Company                  Materialise NV
# Earnings Call Time    Time Not Supplied
# EPS Estimate                      -0.06
# Reported EPS                      -0.04
# Surprise(%)                       28.57
# Date                         2020-07-29
# Name: 1161, dtype: object
# 1161
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             QURE
# Company                    uniQure N.V.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                      -0.67
# Reported EPS                      -0.96
# Surprise(%)                      -43.93
# Date                         2020-07-29
# Name: 1162, dtype: object
# 1162
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                               NEXA
# Company               Nexa Resources S.A.
# Earnings Call Time      Time Not Supplied
# EPS Estimate                        -0.55
# Reported EPS                        -0.44
# Surprise(%)                         20.29
# Date                           2020-07-29
# Name: 1163, dtype: object
# 1163
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             AKSJF
# Company               Sberbank of Russia
# Earnings Call Time     Time Not Supplied
# EPS Estimate                        6.67
# Reported EPS                        7.78
# Surprise(%)                        16.73
# Date                          2020-07-29
# Name: 1165, dtype: object
# 1165
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                              VAL
# Company                     Valaris plc
# Earnings Call Time    Time Not Supplied
# EPS Estimate                      -1.51
# Reported EPS                      -1.55
# Surprise(%)                       -2.38
# Date                         2020-07-29
# Name: 1167, dtype: object
# 1167
# --------------
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - VALPQ: No data found for this date range, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# Symbol                              TOT
# Company                        TOTAL SE
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       -0.2
# Reported EPS                       0.05
# Surprise(%)                      124.12
# Date                         2020-07-29
# Name: 1169, dtype: object
# 1169
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                            TTFNF
# Company                        TOTAL SE
# Earnings Call Time    Time Not Supplied
# EPS Estimate                      -0.23
# Reported EPS                       0.05
# Surprise(%)                       120.6
# Date                         2020-07-29
# Name: 1170, dtype: object
# 1170
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                            TEFOF
# Company                Telefónica, S.A.
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       0.11
# Reported EPS                       0.12
# Surprise(%)                        9.09
# Date                         2020-07-29
# Name: 1171, dtype: object
# 1171
# --------------
# [*********************100%***********************]  1 of 1 completed
# Symbol                             TZOO
# Company                       Travelzoo
# Earnings Call Time    Time Not Supplied
# EPS Estimate                       -0.2
# Reported EPS                      -0.21
# Surprise(%)                          -5
# Date                         2020-07-29
# Name: 1172, dtype: object
# 1172
# --------------
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# 964 stocks have financials: volume of trade, volume_rise (in stocks amount), and returns
len(array_tickers)
# Out:
# 1003

# %% [markdown]
# ## 4.4) Merge all together

# %%
returns_df = pd.DataFrame(columns=['Ticker', 'Returns','Volume Rise','Volume Trade USD','Returns S&P500'])

returns_df = pd.DataFrame([array_tickers,array_returns,array_volume_rise,array_volume_usd, array_snp500]).transpose()

returns_df.columns=['Ticker','Returns','Volume Rise','Volume Trade USD', 'Returns S&P500']

returns_df.set_index('Ticker',inplace=True)

returns_df.dropna(inplace=True)

# %%
returns_df['Returns'] = returns_df['Returns'].astype(float)
returns_df['Volume Rise'] = returns_df['Volume Rise'].astype(float)
returns_df['Volume Trade USD'] = returns_df['Volume Trade USD'].astype(float)
returns_df['Returns S&P500'] = returns_df['Returns S&P500'].astype(float)

# %%
returns_df['Returns in %'] = np.exp(returns_df['Returns'])
returns_df['Volume Rise in %'] = np.exp(returns_df['Volume Rise'])

# Returns above S&P500
returns_df['Adj. Returns'] = returns_df['Returns'] - returns_df['Returns S&P500']
returns_df['Adj. Returns in %'] = np.exp(returns_df['Adj. Returns'])

# %%
# if we want to have a hist -> no INF values
returns_df = returns_df.replace([np.inf, -np.inf], np.nan)

# %%
returns_df.hist(figsize=(20,10), bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd9a9abaf28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd9a916cf28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd9a95aa2e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd9a963c668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd9aa3959e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd9aa3d0d68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd9a9f0a1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd9a9d96d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd9a9d962b0>]],
#       dtype=object)

# %%
stocks_and_returns = stocks_df_noMissing.set_index('Symbol').join(returns_df)

stocks_and_returns.head()
# Out:
#                            Company  ... Adj. Returns in %
# AA               Alcoa Corporation  ...          1.131248
# AAL   American Airlines Group Inc.  ...          1.030482
# AAN                  Aaron's, Inc.  ...          1.189462
# AAPL                    Apple Inc.  ...          1.116626
# AAT    American Assets Trust, Inc.  ...               NaN
#
# [5 rows x 14 columns]

# %%
stocks_and_returns_no_missing = stocks_and_returns.replace([np.inf, -np.inf], np.nan).dropna()

# %%
stocks_and_returns_no_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 993 entries, AA to ZEN
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Company             993 non-null    object
#  1   Earnings Call Time  993 non-null    object
#  2   EPS Estimate        993 non-null    float64
#  3   Reported EPS        993 non-null    float64
#  4   Surprise(%)         993 non-null    float64
#  5   Date                993 non-null    object
#  6   Returns             993 non-null    float64
#  7   Volume Rise         993 non-null    float64
#  8   Volume Trade USD    993 non-null    float64
#  9   Returns S&P500      993 non-null    float64
#  10  Returns in %        993 non-null    float64
#  11  Volume Rise in %    993 non-null    float64
#  12  Adj. Returns        993 non-null    float64
#  13  Adj. Returns in %   993 non-null    float64
# dtypes: float64(11), object(3)
# memory usage: 116.4+ KB

# %%
# TOP 50 most traded stocks 
top50_volume = stocks_and_returns_no_missing.sort_values(by='Volume Trade USD', ascending=False).head(50)

# %%
top50_volume
# Out:
#                                                  Company  ... Adj. Returns in %
# TSLA                                         Tesla, Inc.  ...          1.007584
# AAPL                                          Apple Inc.  ...          1.116626
# AMZN                                    Amazon.com, Inc.  ...          1.088989
# MSFT                               Microsoft Corporation  ...          0.954365
# FB                                        Facebook, Inc.  ...          1.113364
# NFLX                                       Netflix, Inc.  ...          0.971666
# INTC                                   Intel Corporation  ...          0.854742
# GOOGL                                      Alphabet Inc.  ...          1.012108
# GOOG                                       Alphabet Inc.  ...          1.016598
# BA                                    The Boeing Company  ...          0.971359
# BA                                    The Boeing Company  ...          0.971359
# BA                                    The Boeing Company  ...          0.971359
# BA                                    The Boeing Company  ...          0.971359
# QCOM                               QUALCOMM Incorporated  ...          1.126093
# PYPL                               PayPal Holdings, Inc.  ...          1.091958
# SHOP                                        Shopify Inc.  ...          1.054863
# BAC                          Bank of America Corporation  ...          0.977713
# MA                               Mastercard Incorporated  ...          1.024123
# GILD                               Gilead Sciences, Inc.  ...          0.949832
# NOW                                     ServiceNow, Inc.  ...          1.008084
# GS                         The Goldman Sachs Group, Inc.  ...          1.023716
# TEAM                           Atlassian Corporation Plc  ...          0.969853
# UNH                      UnitedHealth Group Incorporated  ...          1.038252
# T                                              AT&T Inc.  ...          0.992880
# ADP                      Automatic Data Processing, Inc.  ...          0.925091
# CMG                         Chipotle Mexican Grill, Inc.  ...          0.977777
# JNJ                                    Johnson & Johnson  ...          1.015571
# PG                          The Procter & Gamble Company  ...          1.042210
# FE                                     FirstEnergy Corp.  ...          0.967811
# CMCSA                                Comcast Corporation  ...          1.022414
# LRCX                            Lam Research Corporation  ...          1.042195
# EHTH                                       eHealth, Inc.  ...          0.811487
# EXPE                                 Expedia Group, Inc.  ...          0.967875
# MS                                        Morgan Stanley  ...          1.019344
# TDOC                                Teladoc Health, Inc.  ...          1.005516
# ASML                                   ASML Holding N.V.  ...          0.972396
# VRTX                 Vertex Pharmaceuticals Incorporated  ...          1.000929
# GE                              General Electric Company  ...          0.974879
# LLY                                Eli Lilly and Company  ...          0.958636
# ABT                                  Abbott Laboratories  ...          1.034567
# F                                     Ford Motor Company  ...          0.994391
# TSM    Taiwan Semiconductor Manufacturing Company Lim...  ...          1.015705
# LIN                                            Linde plc  ...          1.014709
# ORLY                           O'Reilly Automotive, Inc.  ...          1.056859
# ALGN                              Align Technology, Inc.  ...          0.979686
# DLR                           Digital Realty Trust, Inc.  ...          1.059060
# SPOT                             Spotify Technology S.A.  ...          0.949651
# PPG                                 PPG Industries, Inc.  ...          1.060516
# QRVO                                         Qorvo, Inc.  ...          1.080010
# TMO                        Thermo Fisher Scientific Inc.  ...          1.015020
#
# [50 rows x 14 columns]

# %%
top200_volume = stocks_and_returns_no_missing.sort_values(by='Volume Trade USD', ascending=False).head(200)

# %% [markdown]
# # 5) Analysis and visualisation

# %%
#TOP 50: Most of the largest stocks try to report with Surprise<100%
top50_volume[['Surprise(%)','Returns in %']].plot.scatter(x='Surprise(%)', y='Returns in %')

# %%
# TOP 200: Similar to top 50 : but "wider around 0 surprise and returns can be higher (up to 30% in 2 days)"
top200_volume[['Surprise(%)','Returns in %']].plot.scatter(x='Surprise(%)', y='Returns in %')

# %%
# TOP 50: Surprise and Reported EPS vs. Returns in %

# HACK : we need subplots to show the axis value
# https://stackoverflow.com/questions/43121584/matplotlib-scatterplot-x-axis-labels
import matplotlib.pyplot as plt
fig, ax = plt.subplots()


top50_volume[['Surprise(%)','Reported EPS','Returns in %']].plot.scatter(x='Reported EPS', y='Surprise(%)', c='Returns in %', colormap='RdYlGn', ax=ax)

# %%
# TOP 200: Surprise and Reported EPS vs. Returns in %
  # Comment: more examples of moderate returns, negative Reported EPS tends to have negative Returns in %

# HACK : we need subplots to show the axis value
# https://stackoverflow.com/questions/43121584/matplotlib-scatterplot-x-axis-labels
fig, ax = plt.subplots()

top200_volume[['Surprise(%)','Reported EPS','Returns in %']].plot.scatter(x='Reported EPS', y='Surprise(%)', c='Returns in %', colormap='RdYlGn', ax=ax)

# %%
# TOP50: Surprise and Reported EPS vs. Adj. Returns in %
  # COMMENT: many stocks have Reported EPS between 0 and 2.5 USD, and positive returns
fig, ax = plt.subplots()


top50_volume[['Surprise(%)','Reported EPS','Adj. Returns in %']].plot.scatter(x='Reported EPS', y='Surprise(%)', c='Adj. Returns in %', colormap='RdYlGn', ax=ax)

# %%
# TOP200: Surprise and Reported EPS vs. Adj. Returns in %
  # COMMENT: less clear picture with many small positive/negative returns
fig, ax = plt.subplots()


top200_volume[['Surprise(%)','Reported EPS','Adj. Returns in %']].plot.scatter(x='Reported EPS', y='Surprise(%)', c='Adj. Returns in %', colormap='RdYlGn', ax=ax)

# %%
# Reported EPS and EPS Estimate vs Returns in %
fig, ax = plt.subplots()

top50_volume.plot.scatter(x='Reported EPS', y='EPS Estimate', c='Returns in %', colormap='RdYlGn', ax=ax)

# %%
# Reported EPS and EPS Estimate vs. Adj.Returns in %
  # COMMENT : similar picture of Adj. Returns vs. Returns

fig, ax = plt.subplots()

top50_volume.plot.scatter(x='Reported EPS', y='EPS Estimate', c='Adj. Returns in %', colormap='RdYlGn', ax=ax)

# %%
# Compare on returns top 50 and top 200 volume-traded stocks
# TOP 200 stocks have more "bell shaped" distribution around 0 and slightly positive returns vs. top 50 stocks
top200_volume['Adj. Returns in %'].hist(bins=50, alpha=0.5)
top50_volume['Adj. Returns in %'].hist(bins=50, alpha = 0.5)

# %%
# AUXILARY GRAPH - maybe don't need to show in the article
# COMMENT: Very high reported EPS lead to high volume trade ()
fig, ax = plt.subplots()


top200_volume[['Adj. Returns in %','Volume Trade USD','Surprise(%)','Reported EPS']].plot.scatter(x='Adj. Returns in %', y='Volume Trade USD', c='Reported EPS', colormap='RdYlGn', ax=ax)
